# %%
y = [0]
for a in y:
    if a <600:
        a = a + 40
        y.append(a)
    else:
        print (y)
# Out:
# [0, 40, 80, 120, 160, 200, 240, 280, 320, 360, 400, 440, 480, 520, 560, 600]

# %%
x = [0,6,12,20,28,36,40,40,40,40,38,30,20,10,4,0]

# %%
import matplotlib.pyplot as plt
plt.plot(y,x)
plt.xlabel ('Vx')
plt.ylabel ('t')
plt.title ('Graph of the train velocity ''Vx'' against time ''t'' from Oxford to Didcot')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
e = [0]
for a in e:
    if a <60:
        a = a + 5
        e.append(a)
    else:
        print (e)
# Out:
# [0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60]

# %%
d = [0,1.7,6.8,15,26,39,53,68,84,99,115,131,146]
plt.plot(e,d)
plt.show()
