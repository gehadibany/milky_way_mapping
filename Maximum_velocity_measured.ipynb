# %%
import pandas as pd
from bokeh.plotting import figure, output_notebook, show
from bokeh.models.tools import HoverTool

# %%
filename = input('Enter file name:')+'.csv'
data = pd.read_csv (filename, header = 12, skipinitialspace = True)
# Out:
# Enter file name:l 90

# %%
data
# Out:
#      frequency  intensity    velocity  corrected velocity
# 0      -800000     0.0827  168.944750          162.124750
# 1      -795000     0.1584  167.888254          161.068254
# 2      -790000     0.1436  166.831765          160.011765
# 3      -785000     0.1342  165.775284          158.955284
# 4      -780000     0.1178  164.718810          157.898810
# ..         ...        ...         ...                 ...
# 396    1180000     0.1200 -248.846425         -255.666425
# 397    1185000     0.1326 -249.899980         -256.719980
# 398    1190000     0.1397 -250.953527         -257.773527
# 399    1195000     0.1356 -252.007068         -258.827068
# 400    1200000     0.1386 -253.060600         -259.880600
#
# [401 rows x 4 columns]

# %%
output_notebook() 
p = figure(title = "velocity graph", x_axis_label = 'Velocity', y_axis_label = 'intensity', plot_width=800, plot_height=300)
p.line(data['corrected velocity'], data['intensity'])
p.add_tools(HoverTool(mode='vline'))
show(p)

import matplotlib.pyplot as plt
plt.figure (figsize=(8,3))
plt.plot (data['corrected velocity'], data['intensity'])
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="7be2f031-07c2-4678-ad04-dc79b6ec531f" data-root-id="1003"></div>
